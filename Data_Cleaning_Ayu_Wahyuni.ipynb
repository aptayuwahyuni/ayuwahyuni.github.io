# %% [markdown]
# # Loading DataFrame

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
# %ls
# Out:
# 'Copy of telco_customer_churn.csv'  'telco_customer_churn (1).csv'
#  sample_data/                        telco_customer_churn.csv

# %%
# Mengimport Data dari Local
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e7abf07e-952e-4d5a-a4ae-3169099b680f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7abf07e-952e-4d5a-a4ae-3169099b680f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving telco_customer_churn.csv to telco_customer_churn (1).csv

# %%
pd.DataFrame?

# %%
df = pd.read_csv('telco_customer_churn.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # Data Frame Information Exploration

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# # DataFrame Rename

# %%
df = df.rename(columns={'customerID': 'CustID'})
df.columns
# Out:
# Index(['CustID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['custid', 'gender', 'seniorcitizen', 'partner', 'dependents', 'tenure',
#        'phoneservice', 'multiplelines', 'internetservice', 'onlinesecurity',
#        'onlinebackup', 'deviceprotection', 'techsupport', 'streamingtv',
#        'streamingmovies', 'contract', 'paperlessbilling', 'paymentmethod',
#        'monthlycharges', 'totalcharges', 'churn'],
#       dtype='object')

# %% [markdown]
# # DataFrame string function

# %%
df['paymentmethod']
# Out:
# 0                Electronic check
# 1                    Mailed check
# 2                    Mailed check
# 3       Bank transfer (automatic)
# 4                Electronic check
#                   ...
# 7038                 Mailed check
# 7039      Credit card (automatic)
# 7040             Electronic check
# 7041                 Mailed check
# 7042    Bank transfer (automatic)
# Name: paymentmethod, Length: 7043, dtype: object

# %%
df['paymentmethod'] = df['paymentmethod'].str.replace('automatic','')
df['paymentmethod']
# Out:
# 0       Electronic check
# 1           Mailed check
# 2           Mailed check
# 3       Bank transfer ()
# 4       Electronic check
#               ...
# 7038        Mailed check
# 7039      Credit card ()
# 7040    Electronic check
# 7041        Mailed check
# 7042    Bank transfer ()
# Name: paymentmethod, Length: 7043, dtype: object

# %%
df['paymentmethod'] = df['paymentmethod'].str.replace('()','', regex = False)
df['paymentmethod']
# Out:
# 0       Electronic check
# 1           Mailed check
# 2           Mailed check
# 3         Bank transfer
# 4       Electronic check
#               ...
# 7038        Mailed check
# 7039        Credit card
# 7040    Electronic check
# 7041        Mailed check
# 7042      Bank transfer
# Name: paymentmethod, Length: 7043, dtype: object

# %%
df['paymentmethod'] = df['paymentmethod'].str.strip()
df['paymentmethod']
# Out:
# 0       Electronic check
# 1           Mailed check
# 2           Mailed check
# 3          Bank transfer
# 4       Electronic check
#               ...
# 7038        Mailed check
# 7039         Credit card
# 7040    Electronic check
# 7041        Mailed check
# 7042       Bank transfer
# Name: paymentmethod, Length: 7043, dtype: object

# %%
df = pd.read_csv('telco_customer_churn.csv')
# df['paymentmethod.replace(['Bank transfer (automatic)'],'Bank Transfer')
df['PaymentMethod'].str.replace(r" \(automatic*\)","",regex=True)
# Out:
# 0       Electronic check
# 1           Mailed check
# 2           Mailed check
# 3          Bank transfer
# 4       Electronic check
#               ...
# 7038        Mailed check
# 7039         Credit card
# 7040    Electronic check
# 7041        Mailed check
# 7042       Bank transfer
# Name: PaymentMethod, Length: 7043, dtype: object

# %% [markdown]
# # Data Preprocessing

# %%
df['phoneservice']
# Out:
# 0        No
# 1       Yes
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041    Yes
# 7042    Yes
# Name: phoneservice, Length: 7043, dtype: object

# %%
df_phoneservice = df['phoneservice']

# %%
pd.get_dummies(df_phoneservice, columns=['phoneservice'], prefix='phoneservice')
# Out:
#       phoneservice_No  phoneservice_Yes
# 0                   1                 0
# 1                   0                 1
# 2                   0                 1
# 3                   1                 0
# 4                   0                 1
# ...               ...               ...
# 7038                0                 1
# 7039                0                 1
# 7040                1                 0
# 7041                0                 1
# 7042                0                 1
#
# [7043 rows x 2 columns]

# %%
df['monthlycharges']
# Out:
# 0        29.85
# 1        56.95
# 2        53.85
# 3        42.30
# 4        70.70
#          ...
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7041     74.40
# 7042    105.65
# Name: monthlycharges, Length: 7043, dtype: float64

# %%
min_max_scaler = MinMaxScaler ()
df['monthlycharges'] = min_max_scaler.fit_transform(df[['monthlycharges']])
df['monthlycharges']
# Out:
# 0       0.115423
# 1       0.385075
# 2       0.354229
# 3       0.239303
# 4       0.521891
#           ...
# 7038    0.662189
# 7039    0.845274
# 7040    0.112935
# 7041    0.558706
# 7042    0.869652
# Name: monthlycharges, Length: 7043, dtype: float64

# %%
df['totalcharges']
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: totalcharges, Length: 7043, dtype: object

# %%
df.loc[488]['TotalCharges']
# Out:
# ' '

# %%
def isnumber(x):
    try:
        float(x)
        return True
    except:
        return False
df['isnumber'] = df['TotalCharges'].apply(isnumber)
df['isnumber']
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 7038    True
# 7039    True
# 7040    True
# 7041    True
# 7042    True
# Name: isnumber, Length: 7043, dtype: bool

# %%
def isnumber(x):
    try:
        float(x)
        return True
    except:
        return False
df['isnumber'] = df['TotalCharges'].apply(isnumber)
df[~df['isnumber']]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
def isnumber(x):
    try:
        float(x)
        return True
    except:
        return False
df['isnumber'] = df['TotalCharges'].apply(isnumber)
df[~df['isnumber']].index
# Out:
# Int64Index([488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754], dtype='int64')

# %%
def isnumber(x):
    try:
        float(x)
        return True
    except:
        return False
df['isnumber'] = df['TotalCharges'].apply(isnumber)
index_notnumber = df[~df['isnumber']].index

# %%
df.drop(index=index_notnumber)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
median = df[df['isnumber']]['TotalCharges'].astype('float64').median()

# %%
df.loc[index_notnumber,'TotalCharges'] = (median)

# %%
df.loc[index_notnumber]['TotalCharges']
# Out:
# 488     1397.475
# 753     1397.475
# 936     1397.475
# 1082    1397.475
# 1340    1397.475
# 3331    1397.475
# 3826    1397.475
# 4380    1397.475
# 5218    1397.475
# 6670    1397.475
# 6754    1397.475
# Name: TotalCharges, dtype: object

# %%
df['TotalCharges'].astype('float64')
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler ()
totalcharges_scaled = std_scaler.fit_transform(df[['TotalCharges']])
totalcharges_scaled
# Out:
# array([[-0.99424194],
#        [-0.17324413],
#        [-0.95967407],
#        ...,
#        [-0.85446945],
#        [-0.87206242],
#        [ 2.01428802]])
